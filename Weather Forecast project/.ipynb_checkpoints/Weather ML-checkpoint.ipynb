# %%
import pandas as pd

# %%
df = pd.read_csv('Rome_weather_data.csv', index_col='DATE', low_memory=False)

# %%
df.nunique()
# Out:
# STATION              3
# NAME                 3
# LATITUDE             3
# LONGITUDE            3
# ELEVATION            3
# PRCP               450
# PRCP_ATTRIBUTES      8
# SNWD                13
# SNWD_ATTRIBUTES      1
# TAVG               343
# TAVG_ATTRIBUTES      1
# TMAX               403
# TMAX_ATTRIBUTES      7
# TMIN               321
# TMIN_ATTRIBUTES      9
# dtype: int64

# %%
df.sort_index(inplace=True)

# %%
df.tail()
# Out:
#                 STATION                 NAME  LATITUDE  LONGITUDE  ELEVATION  \
# DATE
# 2022-08-18  IT000162240   VIGNA DI VALLE, IT   42.0828    12.2167      266.0
# 2022-08-18  IT000016239    ROMA CIAMPINO, IT   41.7831    12.5831      105.0
# 2022-08-19  IT000162240   VIGNA DI VALLE, IT   42.0828    12.2167      266.0
# 2022-08-19  ITM00016245  PRATICA DI MARE, IT   41.6590    12.4450       12.5
# 2022-08-19  IT000016239    ROMA CIAMPINO, IT   41.7831    12.5831      105.0
#
#             PRCP PRCP_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  \
# DATE
# 2022-08-18   0.0            B,,S   NaN             NaN  27.9            H,,S
# 2022-08-18   0.0            B,,S   NaN             NaN  29.8            H,,S
# 2022-08-19   4.1            B,,S   NaN             NaN  23.9            H,,S
# 2022-08-19   NaN             NaN   NaN             NaN  26.3            H,,S
# 2022-08-19   3.0            B,,S   NaN             NaN  24.9            H,,S
#
#             TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES
# DATE
# 2022-08-18   NaN             NaN   NaN             NaN
# 2022-08-18  35.6             ,,S  24.3             ,,S
# 2022-08-19   NaN             NaN  21.0             ,,S
# 2022-08-19  28.4             ,,S   NaN             NaN
# 2022-08-19  28.4             ,,S   NaN             NaN

# %%
df = df.groupby(df.index).mean()

# %%
df.tail()
# Out:
#              LATITUDE  LONGITUDE   ELEVATION  PRCP  SNWD       TAVG  \
# DATE
# 2022-08-15  41.841633  12.414933  127.833333  0.00   NaN  25.766667
# 2022-08-16  41.841633  12.414933  127.833333  0.50   NaN  26.666667
# 2022-08-17  41.841633  12.414933  127.833333  0.15   NaN  27.800000
# 2022-08-18  41.841633  12.414933  127.833333  0.00   NaN  29.066667
# 2022-08-19  41.841633  12.414933  127.833333  3.55   NaN  25.033333
#
#                  TMAX       TMIN
# DATE
# 2022-08-15  30.633333  20.366667
# 2022-08-16  31.266667  21.666667
# 2022-08-17  33.500000  23.400000
# 2022-08-18  34.800000  24.300000
# 2022-08-19  28.400000  21.000000

# %%
df.apply(pd.isnull).sum()/df.shape[0]
# Out:
# LATITUDE     0.000000
# LONGITUDE    0.000000
# ELEVATION    0.000000
# PRCP         0.007624
# SNWD         0.998966
# TAVG         0.181327
# TMAX         0.004751
# TMIN         0.026282
# dtype: float64

# %%
core_df = df[['PRCP', 'SNWD', 'TMAX', 'TMIN']].copy()

# %%
core_df.columns = ['precip', 'snow_depth', 'temp_max', 'temp_min']

# %%
core_df.head()
# Out:
#             precip  snow_depth  temp_max  temp_min
# DATE
# 1951-03-01     0.2         NaN      13.2       3.0
# 1951-03-02     0.0         NaN      10.5       2.0
# 1951-03-03     0.0         NaN       8.6      -1.4
# 1951-03-04     0.0         NaN      13.6      -2.0
# 1951-03-05     0.1         NaN      15.2       2.7

# %%
core_df.apply(pd.isnull).sum()/core_df.shape[0]
# Out:
# precip        0.007624
# snow_depth    0.998966
# temp_max      0.004751
# temp_min      0.026282
# dtype: float64

# %%
del core_df['snow_depth']

# %%
core_df.loc['1978-10-10':'1978-10-25',:]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1978-10-10     9.6     22.25     12.10
# 1978-10-11     0.0     24.10     11.90
# 1978-10-12     0.0     25.20     12.50
# 1978-10-13     0.0     24.85     12.75
# 1978-10-14     0.0     23.70     12.40
# 1978-10-15     0.0     23.25     11.45
# 1978-10-16     0.0     21.85     11.10
# 1978-10-17     0.0     20.20      9.90
# 1978-10-18     0.0     20.40     12.60
# 1978-10-19     0.0     22.45     12.55
# 1978-10-20     0.0     19.90     13.95
# 1978-10-21    19.2     19.60     11.80
# 1978-10-22    19.2     18.75      9.10
# 1978-10-23    19.2     19.80      7.00
# 1978-10-24    19.2     21.20      8.80
# 1978-10-25    19.2     19.45      8.45

# %%
core_df.ffill(axis=0, inplace=True)

# %%
core_df.apply(pd.isnull).sum()/core_df.shape[0]
# Out:
# precip      0.0
# temp_max    0.0
# temp_min    0.0
# dtype: float64

# %%
core_df.index
# Out:
# Index(['1951-03-01', '1951-03-02', '1951-03-03', '1951-03-04', '1951-03-05',
#        '1951-03-06', '1951-03-07', '1951-03-08', '1951-03-09', '1951-03-10',
#        ...
#        '2022-08-10', '2022-08-11', '2022-08-12', '2022-08-13', '2022-08-14',
#        '2022-08-15', '2022-08-16', '2022-08-17', '2022-08-18', '2022-08-19'],
#       dtype='object', name='DATE', length=26102)

# %%
core_df.index = pd.to_datetime(core_df.index)

# %%
core_df.index
# Out:
# DatetimeIndex(['1951-03-01', '1951-03-02', '1951-03-03', '1951-03-04',
#                '1951-03-05', '1951-03-06', '1951-03-07', '1951-03-08',
#                '1951-03-09', '1951-03-10',
#                ...
#                '2022-08-10', '2022-08-11', '2022-08-12', '2022-08-13',
#                '2022-08-14', '2022-08-15', '2022-08-16', '2022-08-17',
#                '2022-08-18', '2022-08-19'],
#               dtype='datetime64[ns]', name='DATE', length=26102, freq=None)

# %%
core_df[['temp_max', 'temp_min']].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_df.apply(lambda x: (x==999).sum())
# Out:
# precip      0
# temp_max    3
# temp_min    5
# dtype: int64

# %%
extreme_temps = core_df[core_df['temp_max'] > core_df['temp_max'].quantile(q=0.9985)]

# %%
core_df.loc['1956-02-01':'1956-02-15',:]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1956-02-01     2.0      6.60     -0.50
# 1956-02-02     6.6      2.90     -2.35
# 1956-02-03     0.0      3.00     -2.40
# 1956-02-04     0.0      3.60     -3.20
# 1956-02-05     0.0      3.85     -4.20
# 1956-02-06     0.0      3.35     -3.80
# 1956-02-07     0.0      3.45     -3.00
# 1956-02-08     0.0      2.45     -3.85
# 1956-02-09     2.6    501.15     -3.90
# 1956-02-10     9.6      4.15     -1.60
# 1956-02-11    10.0      4.00     -0.50
# 1956-02-12     1.0      5.65     -2.45
# 1956-02-13     4.0      4.45     -1.70
# 1956-02-14     0.3      1.25     -3.85
# 1956-02-15     0.2      1.05     -4.90

# %%
core_df.describe().transpose()
# Out:
#             count       mean        std   min   25%   50%        75%    max
# precip    26102.0   2.250332   6.823393  0.00   0.0   0.0   0.500000  213.0
# temp_max  26102.0  20.813576  20.564727 -2.15  14.1  19.6  26.466667  999.0
# temp_min  26102.0  11.706327  24.527919 -7.70   5.9  10.6  15.933333  999.0

# %%
extreme_temps
# Out:
#             precip  temp_max    temp_min
# DATE
# 1956-02-09     2.6    501.15   -3.900000
# 1956-08-07     0.0     37.85   19.300000
# 1956-08-08     0.0     38.90   24.250000
# 1961-02-15     0.0    508.00    2.750000
# 1963-01-20    10.0    501.50    0.450000
# 1964-07-06     0.0    514.20   20.200000
# 1965-02-11     0.0    504.10   -3.000000
# 1965-03-28     0.0    509.90    6.200000
# 1965-04-16     0.0    508.10    4.900000
# 1965-05-02     1.2    509.30    6.850000
# 1965-09-26     1.2    511.80   16.500000
# 1965-11-20     0.0    508.50    8.600000
# 1965-12-01     0.0    505.85    4.000000
# 1965-12-21     0.8    507.30    8.000000
# 1967-06-27     0.0    515.20   14.900000
# 1967-07-07     0.2    515.00   17.950000
# 1967-07-25     0.0     37.90   21.700000
# 1967-10-20     0.0    511.00    8.000000
# 1969-01-25     0.0    506.20    0.700000
# 1974-05-11     0.2    510.50    8.600000
# 1975-02-26     0.0    505.60    0.450000
# 1978-01-05     0.0    504.30  500.800000
# 1978-06-30     0.0    513.10  505.600000
# 1978-07-05     0.1    512.30   14.000000
# 1981-08-04     0.0     39.65   21.950000
# 1983-07-28     0.0     38.95   22.150000
# 1984-12-30     0.0    505.10  502.100000
# 1985-01-25     0.0    504.40    2.550000
# 1988-07-03     0.0    513.80   17.400000
# 1999-04-05     0.6    509.80    8.100000
# 1999-12-17    35.6    999.00  999.000000
# 1999-12-18     0.0    505.10  500.300000
# 1999-12-19     0.0    999.00  999.000000
# 2000-01-14     0.0    999.00  999.000000
# 2001-01-14     0.0    505.50  501.800000
# 2001-01-15     0.2    339.20  336.000000
# 2001-10-01     0.0    512.70  344.666667
# 2007-08-25     0.0     39.30   21.800000
# 2017-08-01     0.0     38.50   22.300000
# 2022-06-27     0.0     38.50   22.850000

# %%
core_df['precip'].describe().transpose()
# Out:
# count    26102.000000
# mean         2.250332
# std          6.823393
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.500000
# max        213.000000
# Name: precip, dtype: float64

# %%
def IQR_calc(column):
    Q1 = core_df[column].quantile(0.25)
    Q3 = core_df[column].quantile(0.75)
    return Q3 - Q1

# %%
IQR_temp_min = IQR_calc('temp_min')

lower_lim_min = core_df['temp_min'].quantile(0.25) - 5 * IQR_temp_min
upper_lim_min = core_df['temp_min'].quantile(0.75) + 5 * IQR_temp_min

# %%
print(lower_lim_min, upper_lim_min)
# Out:
# -44.26666666666666 66.1

# %%
IQR_temp_max = IQR_calc('temp_max')

lower_lim_max = core_df['temp_max'].quantile(0.25) - 5 *IQR_temp_max
upper_lim_max = core_df['temp_max'].quantile(0.75) + 5 *IQR_temp_max

# %%
print(lower_lim_max, upper_lim_max)
# Out:
# -47.73333333333334 88.30000000000001

# %%
IQR_precip = IQR_calc('precip')

lower_lim_precip = core_df['precip'].quantile(0.25) - 5 * IQR_precip
upper_lim_precip = core_df['precip'].quantile(0.75) + 5 * IQR_precip

# %%
print(lower_lim_precip, upper_lim_precip)
# Out:
# -2.5 3.0

# %%
core_df[core_df['temp_max'] > upper_lim_max] = 0

# %%
core_df
# Out:
#             precip   temp_max   temp_min
# DATE
# 1951-03-01    0.20  13.200000   3.000000
# 1951-03-02    0.00  10.500000   2.000000
# 1951-03-03    0.00   8.600000  -1.400000
# 1951-03-04    0.00  13.600000  -2.000000
# 1951-03-05    0.10  15.200000   2.700000
# ...            ...        ...        ...
# 2022-08-15    0.00  30.633333  20.366667
# 2022-08-16    0.50  31.266667  21.666667
# 2022-08-17    0.15  33.500000  23.400000
# 2022-08-18    0.00  34.800000  24.300000
# 2022-08-19    3.55  28.400000  21.000000
#
# [26102 rows x 3 columns]
